# %% [markdown]
# # 密な固有名詞クラスタを算出

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import pickle

# %%
f = open('../koyuu_noun_sample_list.binaryfile','rb')
sample_noun_vec_list = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-2-3d8f9005fd7c> in <module>
#       1 f = open('../koyuu_noun_sample_list.binaryfile','rb')
# ----> 2 sample_noun_vec_list = pickle.load(f)
#
# EOFError: Ran out of input

# %%
# 密なクラスタを算出

eps_minPts = {}
minPts_data = {}

print("noun_vec_list数 : ", len(sample_noun_vec_list))

for eps in range(4,50,1):
    eps = eps/10
    
    for minPts in range(10,200, 5):
        dbscan = DBSCAN(eps=eps,min_samples=minPts).fit(sample_noun_vec_list)
        
        y_dbscan = dbscan.labels_
        
        print("y_dbscan", y_dbscan)
        
        print("eps:",eps,",minPts:", minPts)
        
        # outlier数
        print("outlier数", len(np.where(y_dbscan ==-1)[0]))
        
        # クラスタ数
        print("クラスタ数", np.max(y_dbscan) +2)
        
        print("                            ")
        
        minPts_data[minPts] = y_dbscan
        eps_minPts[eps] = minPts_data
        
    # DBSCANの結果を保存
    f_name = str(eps) + "_" + str(minPts) + "_dic.binaryfile"
    f = open("../dbscan_koyuu_noun_fold/" + f_name,'wb')
    pickle.dump(eps_minPts,f)
    f.close
    break

# %%
# DBSCANの結果を保存

f = open('../dbscan_dic.binaryfile','wb')
pickle.dump(eps_minPts,f)
f.close
